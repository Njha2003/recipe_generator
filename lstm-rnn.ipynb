# %%
import json
import re
import string
import tensorflow as tf
from tensorflow import keras
from collections import Counter

# %%
import numpy as np

# %%
with open('/kaggle/input/epirecipes/full_format_recipes.json') as json_data:
    recipe = json.load(json_data)

# %%
keys=set()
for recipes in recipe:
    for key in recipes.keys():
        keys.add(key)
print(keys)
# Out:
# {'categories', 'ingredients', 'fat', 'title', 'rating', 'calories', 'directions', 'sodium', 'date', 'protein', 'desc'}

# %%
filter_data = ["Recipe for "+x['title']+' | '+" ".join(x['directions'])
              for x in recipe
              if 'title' in x
              and x['title'] is not None
              and 'directions' in x
              and x['directions'] is not None]

# %%
print(filter_data[20100])
print(len(filter_data))
# Out:
# Recipe for Chicken with White Wine and Herbs  | In a large pot, place the chicken legs, bay leaves, tarragon, peppercorns, parsley stalks, white wine, and 2 celery stalks. Halve two of the onions and two of the carrots and add to the pan, then pour in enough cold water to cover the legs (about 2 quarts). Cover the pan and bring to a boil, then reduce to a simmer and cook, with the lid half on, for 25 minutes, or until juices in the legs run clear. Remove the chicken legs from the pan and set aside, but keep the stock simmering. Meanwhile, chop the remaining onions, carrot, and celery into small chunks. In a large saucepan over low heat, heat the butter, add the chopped vegetables and a pinch of salt, and sweat for 6 to 8 minutes. Meanwhile, strip the chicken from the bones and set aside. Place the bones, skin, and trimmings back in the simmering stock pot and continue to simmer. Add the mushrooms and garlic to the pan with the chopped vegetables and turn up the heat to brown all the ingredients, 3 to 4 minutes. Stir in the flour and cook gently for a minute. Strain the stock into a measuring cup and measure out 3 1/3 cups (you can freeze any extra). Add nearly all of the stock and the soy sauce to the pan of vegetables, stirring it in slowly until it comes back to a simmer and thickens. Add a little more stock if it is still too thick- it should be thick enough to coat the back of a spoon. Chop the parsley leaves and add to the pan, along with the chicken. Stir in the cream, then taste and adjust seasoning as needed.
# 20111

# %%
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def pad_punc(s):
    s = re.sub(f"([{string.punctuation}])", r' \1 ', s)
    s = re.sub(' +', ' ', s)
    return s
text_data = [pad_punc(x) for x in filter_data]

# %%
print(len(text_data))
tokens = ' '.join(text_data).split()
tokens_count = Counter(tokens)
# for token, count in tokens_count.items():
#     print(f"{token}: {count}")
print(len(tokens_count))
# Out:
# 20111
# 16407

# %%
example_data=text_data[1]
print(example_data)
# Out:
# Recipe for Boudin Blanc Terrine with Red Onion Confit | Combine first 9 ingredients in heavy medium saucepan . Add 3 shallots . Bring to simmer . Remove from heat , cover and let stand 30 minutes . Chill overnight . Preheat oven to 325°F . Line 7 - cup pâté or bread pan with plastic wrap . Melt butter in heavy small skillet over low heat . Add remaining 5 shallots . Cover and cook until very soft , stirring occasionally , about 15 minutes . Transfer to processor . Add pork , eggs , flour and Port and puree . Strain cream mixture , pressing on solids to extract as much liquid as possible . With processor running , add cream through feed tube and process just until combined with pork . Transfer to large bowl . Mix in currants . Spoon mixture into prepared pan . Cover with foil . Place pan in large pan . Add boiling water to larger pan to within 1 / 2 inch of top of terrine . Bake until terrine begins to shrink from sides of pan and knife inserted into center comes out clean , about 1 1 / 2 hours . Uncover and cool on rack . Chill until cold . ( Can be made 3 days ahead . Cover and chill . ) Line platter with lettuce . Arrange terrine atop . Sprinkle with pepper and parsley . Garnish with bay leaves . Spoon confit around sides . Serve with bread . Heat oil in heavy large skillet over medium - high heat . Add onions and sauté until crisp - tender , about 8 minutes . Add all remaining ingredients and stir until reduced to thick glaze , about 4 minutes . Season with salt and pepper . ( Can be prepared 2 days ahead . Cover and chill . ) Serve warm or at room temperature .

# %%
text_dataset = tf.data.Dataset.from_tensor_slices(text_data).batch(64).shuffle(1000)
vector_layer=keras.layers.TextVectorization(standardize='lower',max_tokens=13000,output_mode='int',output_sequence_length=200+1,)
vector_layer.adapt(text_dataset)
vocab=vector_layer.get_vocabulary()

# %%
print(len(vocab))
# Out:
# 12921

# %%
print(vocab[0:11])
example_tokens=vector_layer(example_data)
print(example_tokens.numpy())
print(example_data)
# Out:
# ['', '[UNK]', '.', ',', 'and', 'to', 'in', 'the', 'with', 'a', 'until']
# [  26   16 6055 2618 1359    8  282  115 1677   27  103  329  334  131
#     6   78   29   80    2   18   36  417    2   84    5   70    2   71
#    51   17    3   49    4   67  146  126   12    2  108  435    2   86
#    47    5  677    2  328  343   13   52 2557   41  195   44    8  214
#   212    2  266   50    6   78   65   56   20  134   17    2   18   45
#    59  417    2   49    4   43   10  218  286    3   48   90    3   19
#   127   12    2   40    5  188    2   18  201    3  199    3  111    4
#  1087    4  378    2  320   76   31    3  427   28  493    5  692  151
#   830  143  151  787    2    8  188  703    3   18   76  102 1541 1568
#     4  443   93   10  348    8  201    2   40    5   30   21    2  116
#     6 1270    2   98   31   25  176   44    2   49    8  167    2   64
#    44    6   30   44    2   18  231   39    5 1020   44    5 1617   11
#    23   15   53   14   72   14 1359    2   97   10 1359  549    5 2969
#    51  129   14   44    4  267  369   25  168  444  124  370    3   19
#    11   11   23   15  106]
# Recipe for Boudin Blanc Terrine with Red Onion Confit | Combine first 9 ingredients in heavy medium saucepan . Add 3 shallots . Bring to simmer . Remove from heat , cover and let stand 30 minutes . Chill overnight . Preheat oven to 325°F . Line 7 - cup pâté or bread pan with plastic wrap . Melt butter in heavy small skillet over low heat . Add remaining 5 shallots . Cover and cook until very soft , stirring occasionally , about 15 minutes . Transfer to processor . Add pork , eggs , flour and Port and puree . Strain cream mixture , pressing on solids to extract as much liquid as possible . With processor running , add cream through feed tube and process just until combined with pork . Transfer to large bowl . Mix in currants . Spoon mixture into prepared pan . Cover with foil . Place pan in large pan . Add boiling water to larger pan to within 1 / 2 inch of top of terrine . Bake until terrine begins to shrink from sides of pan and knife inserted into center comes out clean , about 1 1 / 2 hours . Uncover and cool on rack . Chill until cold . ( Can be made 3 days ahead . Cover and chill . ) Line platter with lettuce . Arrange terrine atop . Sprinkle with pepper and parsley . Garnish with bay leaves . Spoon confit around sides . Serve with bread . Heat oil in heavy large skillet over medium - high heat . Add onions and sauté until crisp - tender , about 8 minutes . Add all remaining ingredients and stir until reduced to thick glaze , about 4 minutes . Season with salt and pepper . ( Can be prepared 2 days ahead . Cover and chill . ) Serve warm or at room temperature .

# %%
# Check if full stop or comma exists in the vocabulary
contains_full_stop = '.' in vocab
contains_comma = ',' in vocab

print("Full stop exists:", contains_full_stop)
print("Comma exists:", contains_comma)
# Out:
# Full stop exists: True
# Comma exists: True

# %%
# Get the index of full stop and comma in the vocabulary
full_stop_index = vocab.index('.')
comma_index = vocab.index(',')

print("Index of full stop:", full_stop_index)
print("Index of comma:", comma_index)
# Out:
# Index of full stop: 2
# Index of comma: 3

# %%
def prepare_data(text):
    text = tf.expand_dims(text,-1)
    token_text = vector_layer(text)
    x = token_text[:,:-1]
    y = token_text[:,1:]
    return x,y
train_ds = text_dataset.map(prepare_data)

# %%
inputs = keras.layers.Input(shape=(None,),dtype='int32')
x = keras.layers.Embedding(13000,150)(inputs)
x = keras.layers.Bidirectional(keras.layers.GRU(150,return_sequences=True))(x)
x = keras.layers.Bidirectional(keras.layers.GRU(150,return_sequences=True))(x)
# x = keras.layers.LSTM(128,return_sequences=True)(x)
output = keras.layers.Dense(13000,activation='softmax')(x)
lstm_model = keras.models.Model(inputs,output)
lstm_model.compile(optimizer='adam',loss=keras.losses.SparseCategoricalCrossentropy())

# %%
lstm_model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, None)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_4 (Embedding)         │ (None, None, 150)      │     1,950,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, None, 300)      │       271,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, None, 300)      │       406,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, None, 13000)    │     3,913,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,541,600 (24.95 MB)
#  Trainable params: 6,541,600 (24.95 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
class TextGenerator(keras.callbacks.Callback):
    def __init__(self, index_to_word, top_k=10):
        self.index_to_word = index_to_word
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  # <1>

    def sample_from(self, probs, temperature):  # <2>
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  # <4>
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  # <5>
            sample_token, probs = self.sample_from(y[0][-1], temperature)  # <6>
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)  # <7>
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("recipe for", max_tokens=100, temperature=0.6)

# %%
text_generator=TextGenerator(vocab)

# %%
lstm_model.fit(train_ds,epochs=20,callbacks=[text_generator])
# Out:
# Epoch 1/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 5.2072
# generated text:
# recipe for with
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 70s 214ms/step - loss: 5.2049
# Epoch 2/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 3.6913
# generated text:
# recipe for stuffed with for for salad sheet of into the a a for a tablespoons sheet in " . can with top and with available
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 68s 216ms/step - loss: 3.6904
# Epoch 3/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 2.7040
# generated text:
# recipe for a oven oven first " | the 1 bowl , 4 in a a in a a sides and too more . cut to disk and inch . put tortillas to the the 3 not 1 out inch in heavy a dough to 2 often , 2 sheet 2 until tender heat 4 until 1 dish with clean the 25 to pan together cooking , 2 large pan over 2 until brown until work ; cooked to a the . cook and cloves . about and about small pan and about a 4 until 1 pan atop smooth
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 72s 230ms/step - loss: 2.7034
# Epoch 4/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 1.9258
# generated text:
# recipe for and cake | medium processor . divide
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 67s 213ms/step - loss: 1.9252
# Epoch 5/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 1.2630
# generated text:
# recipe for s | a excess teaspoon pops , mash in a pieces . least 4 bowl from a 4 bowl , until roasting the out and add the mixture to a small of a tablespoon under the squash , stirring , the have ice the whites of the beans to and the necessary . covered , baking bowl ; let 3 teaspoon 55 , the artichokes , the whites . then preheat the thin . sear 1 / all a 4 teaspoon roasting the wafers . beat broiler to the a 4 - 4 / a baking off the
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 73s 231ms/step - loss: 1.2625
# Epoch 6/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.7175
# generated text:
# recipe for for the yellow . fried . for for cookies , for 1 / baking " and wrap of out of and wrap of baking sheet and trim of - egg of parchment overhang of the springform . spread the
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 69s 220ms/step - loss: 0.7172
# Epoch 7/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 0.3779
# generated text:
# recipe for stuffed springform sheet ; cut , with for nonstick . roll : springform of baking - briquettes frosting . arrange overhang of
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 68s 217ms/step - loss: 0.3777
# Epoch 8/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.2192
# generated text:
# recipe for preheated layer . whisk the parchment three teaspoon fresh cheese , for small - husks with pierce with parchment parchment rack with parchment parchment rack broiler . preheat oven | rack in 2 - inch - inch manner , or parchment parchment parchment parchment rack and springform the parchment parchment pans . transfer layers of the three broiler . parchment parchment paper parchment cake in the parchment parchment parchment parchment parchment parchment parchment parchment parchment parchment parchment parchment place the parchment parchment parchment parchment parchment parchment parchment parchment or parchment parchment parchment parchment pans . 1 / 2
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 73s 231ms/step - loss: 0.2191
# Epoch 9/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.1387
# generated text:
# recipe for pecan fresh raisins . fold broiler as shrimp with pan and for 1 tablespoon time , smoked 82°f . set with large pan and trim overhang with large bowl . using parchment parchment parchment parchment rack / baking bowl with baking cup springform perfectly . olive main of large bowl . fold of muffin - some sticks . gather - prepared pan and switching atop rope broiler . arrange square as parchment parchment rack is edges tenderloin of shallow hours and ) . parchment parchment parchment pans . parchment parchment paper . pans . flatten pin with 16
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 74s 234ms/step - loss: 0.1387
# Epoch 10/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0948
# generated text:
# recipe for parchment parchment parchment rack with egg with parchment parchment parchment rack with preheat into baking sheet of the pickled rack with the parchment rack with parchment rack with rack pastry round of grated bread to parchment parchment rack . 425°f . rack . line waxed parchment parchment parchment pin into rimmed baking sheet of the parchment parchment parchment parchment parchment parchment parchment parchment rack with rack . line slices of the tart in large glass filling . fold biscotti parchment pans with parchment parchment squares as cookie pin into parchment rack and parchment paper heavy large shallow -
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 73s 232ms/step - loss: 0.0948
# Epoch 11/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0697
# generated text:
# recipe for egg with processor . process and pepper , and vegetables and claret . parchment paper teaspoon salt and lime with anglaise with meyer fresh springform pan and freeze , peaks prepared baking - inch cup tart and wrap with graham of constantly of and beat with juice in a baking cup sugar and beat , stirring , and ) : filling and rack . place 6 hours ahead . ice more salt and process . add large small bowl . ice butter and pepper . beat , and three . the vegetable remaining 30 minutes . mix processor
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 73s 232ms/step - loss: 0.0697
# Epoch 12/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0517
# generated text:
# recipe for 1 / 2 cup sauce and puree and skip with rum with parmesan , " filled . preheat to 375°f with ricotta and top with rack with salt and salt and cocoa on plastic wrap with streusel of pan . each pan . line with parmesan with tart until dough with salt and wrap . preheat and wrap with tablespoonfuls : parchment parchment paper made 3 - plastic rolling . toast of pan made 1 / 2 bowl . preheat to prepared pan . preheat in 5 minutes . toast of pan . preheat to blend . if
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 73s 232ms/step - loss: 0.0517
# Epoch 13/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 0.0396
# generated text:
# recipe for for large heat and roast and caper with large pan heat with large medium - skin and pepper . add a boil the onion with large medium - sauté with small saucepan side . add add heat . add the mushrooms . add olive them side . add carrot . sauté , carrot and add until vegetables until skillet and sauté , about large medium bowl , carrot and add the the any reserved , until very pinch and add slotted spoon with large bowl for brown and add the mushrooms , and pepper . toss with sauce
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 74s 233ms/step - loss: 0.0396
# Epoch 14/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 0.0313
# generated text:
# recipe for the sauce and put 2 cup sauce and lobster . preheat oven to the julia of the the sweet onions . put a 2 cup the sauce and chilled pork . drizzle with the sauce .
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 70s 221ms/step - loss: 0.0313
# Epoch 15/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0248
# generated text:
# recipe for for egg with sauce and toss , carrot with switching among 16 oven apart with rack . spread bread bread oven inches each pastry among tart with parchment cookies , preheat oven corner with parchment parchment two rack plates . arrange cookies . rack . line two can be made 1 oven and parsley and switching crisps with parmesan with parmesan and drizzle with sprinkle with rack third of topping and preheat to 450°f with cheese oven parchment paper oven to parchment paper into one long . pour pans . place cake third of drape . arrange cookies
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 73s 233ms/step - loss: 0.0248
# Epoch 16/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 0.0202
# generated text:
# recipe for 3 ingredients . combine with the sauce and carrot of parmesan and pepper . pour with cayenne with carrot with marjoram . toss to blend shallot but of marinated rosemary with carrot . toss to boil . bring to large bowl . cook until the onions and add the onions and simmer the any liquid , about 3 minutes . add sauce . add the cream to large bowl . add dutch oven and pepper . add sauce and cook until too thick but still but still but not smoking , and cayenne of medium heat . add
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 74s 234ms/step - loss: 0.0202
# Epoch 17/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 0.0164
# generated text:
# recipe for biscochitos . place the " mushrooms with the parmesan and pepper with mint and pepper . olive oil with a 325°f and carrot . remove the slices on a large medium bowl . add coarse salt and pepper . whisk the yogurt , carrot . add salt and pepper to boil . the remaining a boil . add the the the the remaining a large bowl , salt and pepper . whisk in the vegetables over medium bowl . taste . olive oil , stirring , stirring , then simmer , until a medium heat , stirring minute
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 73s 233ms/step - loss: 0.0164
# Epoch 18/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0133
# generated text:
# recipe for orange juice , and 3 cup sauce and sauce . line with tomato with sauce , orange sauce . add sauteed back of pan of large skillet and boil . add the rolls and onion with a boil . hot hot any mushrooms , then bring to boil . whisk in the sauce and the cornstarch of small bowl , stirring , cut the cream with the cream in 2 hours . add the ganache of pan . cover and keep with butter with the bloomed with the sauce and top with the can be made 3 cup
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 73s 233ms/step - loss: 0.0133
# Epoch 19/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0113
# generated text:
# recipe for 1 tablespoon butter in medium - inch - duty 2 inches until just just until they are almost but still bubbles and transfer to work surface to filling and let stand at filling , 1 or until top until top , until firm until same manner , about 4 tablespoons sugar , 1 / 2 tablespoons sugar and let stand at room temperature .
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 71s 225ms/step - loss: 0.0113
# Epoch 20/20
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0093
# generated text:
# recipe for the sauce | and cook until wilted . remove pan to a medium speed until wilted that slowly until smooth but still bubbles and parsley and toss to taste with basil and top with the sauce ahead . season with salt and pepper with salt and pepper . the sauce until it is quite not quite needed , and the whites to taste , and salt and pepper to taste and pepper . season with salt and basil and pepper , and parsley , basil and dried dill , and top with the cream with the sauce and
#
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 73s 232ms/step - loss: 0.0094

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %%
info = text_generator.generate(
    "roasted vegetables | chop 1 /", max_tokens=100, temperature=0.5
)
print_probs(info, vocab)
# Out:
# generated text:
# roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture until absorbed until absorbed , stirring occasionally , and
#
#
# PROMPT: roasted vegetables | chop 1 /
# 2:   	82.94%
# 4:   	14.95%
# 3:   	1.36%
# a:   	0.53%
# still:   	0.08%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2
# cup:   	81.76%
# tablespoons:   	6.4%
# bowl:   	3.88%
# 2:   	3.85%
# hours:   	1.76%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup
# sauce:   	17.16%
# pan:   	16.01%
# the:   	4.23%
# sugar:   	4.1%
# cream:   	3.13%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice
# into:   	31.01%
# in:   	25.49%
# or:   	13.37%
# mixture:   	11.26%
# .:   	6.3%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture
# until:   	51.97%
# in:   	42.75%
# ;:   	1.56%
# .:   	1.32%
# ,:   	0.98%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in
# a:   	55.9%
# 2:   	17.54%
# the:   	11.61%
# large:   	8.12%
# baking:   	1.95%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a
# small:   	47.75%
# medium:   	25.57%
# large:   	11.01%
# 2:   	7.2%
# baking:   	5.09%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium
# bowl:   	57.99%
# pot:   	30.44%
# speed:   	5.47%
# medium:   	2.84%
# saucepan:   	1.26%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot
# of:   	83.63%
# .:   	12.31%
# and:   	2.5%
# ,:   	1.14%
# -:   	0.15%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of
# boiling:   	34.74%
# the:   	21.35%
# small:   	13.25%
# until:   	9.15%
# medium:   	6.4%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the
# beans:   	22.03%
# sauce:   	19.56%
# mushrooms:   	17.74%
# broth:   	7.16%
# the:   	4.01%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce
# until:   	75.61%
# and:   	16.15%
# is:   	5.83%
# over:   	1.37%
# ;:   	0.38%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and
# cook:   	32.36%
# vegetables:   	18.05%
# add:   	15.54%
# simmer:   	7.73%
# bring:   	3.77%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add
# the:   	95.2%
# a:   	1.63%
# mixture:   	0.73%
# broth:   	0.45%
# water:   	0.34%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the
# beans:   	37.64%
# mushrooms:   	24.32%
# sauce:   	11.57%
# broth:   	2.82%
# the:   	2.72%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms
# ,:   	81.12%
# to:   	14.18%
# with:   	1.59%
# and:   	1.09%
# in:   	0.54%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms ,
# and:   	88.8%
# until:   	9.23%
# stirring:   	1.14%
# about:   	0.29%
# the:   	0.11%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and
# cook:   	27.5%
# the:   	20.95%
# simmer:   	6.84%
# stirring:   	6.2%
# parsley:   	5.65%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring
# to:   	98.35%
# ,:   	1.33%
# in:   	0.14%
# water:   	0.12%
# towels:   	0.02%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to
# a:   	46.71%
# medium:   	35.2%
# large:   	9.77%
# 2:   	2.36%
# the:   	1.06%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large
# pot:   	75.43%
# skillet:   	12.25%
# bowl:   	7.56%
# medium:   	3.95%
# batches:   	0.31%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot
# of:   	44.3%
# and:   	33.36%
# .:   	20.33%
# ,:   	1.32%
# but:   	0.24%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of
# boiling:   	57.77%
# until:   	19.0%
# the:   	5.09%
# medium:   	4.8%
# small:   	4.68%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until
# absorbed:   	46.36%
# it:   	10.65%
# wilted:   	9.37%
# smooth:   	5.39%
# thickened:   	3.36%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it
# is:   	57.91%
# ;:   	35.44%
# are:   	1.67%
# ,:   	1.15%
# just:   	0.78%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is
# very:   	41.48%
# hot:   	8.93%
# slightly:   	8.33%
# crisp:   	6.88%
# just:   	6.34%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated
# through:   	89.46%
# cups:   	9.83%
# hours:   	0.22%
# minute:   	0.1%
# of:   	0.08%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through
# ,:   	81.83%
# and:   	14.15%
# .:   	3.45%
# to:   	0.21%
# the:   	0.14%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through ,
# stirring:   	44.68%
# until:   	27.02%
# about:   	12.73%
# and:   	11.04%
# cook:   	1.68%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until
# absorbed:   	36.03%
# it:   	16.99%
# smooth:   	7.27%
# very:   	6.58%
# wilted:   	5.07%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed
# is:   	45.13%
# ,:   	32.11%
# until:   	20.1%
# and:   	1.52%
# .:   	0.32%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed ,
# stirring:   	43.3%
# until:   	30.32%
# and:   	16.88%
# about:   	6.77%
# cook:   	0.83%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and
# cook:   	31.83%
# the:   	22.68%
# add:   	14.93%
# stirring:   	9.27%
# simmer:   	7.8%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add
# the:   	97.31%
# mixture:   	0.59%
# a:   	0.32%
# juice:   	0.24%
# pan:   	0.24%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the
# broth:   	20.33%
# the:   	17.52%
# mushrooms:   	11.31%
# beans:   	9.42%
# mixture:   	6.54%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the
# broth:   	25.46%
# the:   	15.85%
# beans:   	7.55%
# sauce:   	7.18%
# mushrooms:   	6.46%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce
# is:   	38.63%
# and:   	36.19%
# until:   	20.69%
# ,:   	1.48%
# over:   	0.87%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until
# it:   	43.37%
# absorbed:   	30.65%
# smooth:   	7.78%
# they:   	2.65%
# thickened:   	2.29%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it
# is:   	50.7%
# ;:   	38.27%
# ,:   	3.33%
# are:   	2.57%
# all:   	1.66%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ;
# bring:   	17.91%
# cook:   	16.92%
# add:   	16.19%
# simmer:   	13.88%
# fluff:   	12.18%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add
# the:   	94.14%
# mixture:   	1.44%
# a:   	0.8%
# broth:   	0.8%
# dried:   	0.32%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the
# mushrooms:   	19.37%
# beans:   	18.41%
# broth:   	15.48%
# the:   	9.0%
# sauce:   	8.97%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright
# .:   	36.82%
# -:   	24.07%
# ,:   	16.37%
# and:   	12.7%
# pot:   	3.97%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright .
# add:   	59.44%
# simmer:   	13.19%
# cook:   	6.0%
# toss:   	4.24%
# bring:   	3.43%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add
# the:   	51.2%
# a:   	27.88%
# mixture:   	10.14%
# remaining:   	2.11%
# juice:   	1.75%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a
# large:   	40.63%
# medium:   	33.37%
# small:   	10.05%
# the:   	9.18%
# 2:   	2.99%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large
# bowl:   	61.21%
# pot:   	18.63%
# skillet:   	10.18%
# medium:   	6.46%
# batches:   	1.38%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl
# and:   	62.8%
# .:   	19.88%
# ,:   	8.63%
# until:   	6.53%
# ;:   	0.38%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and
# cook:   	53.86%
# add:   	16.08%
# vegetables:   	6.2%
# simmer:   	3.56%
# discard:   	3.4%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook
# until:   	57.39%
# ,:   	35.64%
# in:   	5.88%
# water:   	0.49%
# the:   	0.22%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until
# wilted:   	67.28%
# absorbed:   	10.13%
# bright:   	4.5%
# vegetables:   	3.97%
# fragrant:   	1.88%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted
# .:   	99.86%
# ,:   	0.06%
# that:   	0.02%
# with:   	0.01%
# as:   	0.01%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted .
# add:   	59.89%
# simmer:   	14.63%
# cook:   	6.13%
# bring:   	3.77%
# toss:   	3.51%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return
# a:   	37.57%
# the:   	22.31%
# mixture:   	14.27%
# skillet:   	2.85%
# pan:   	2.49%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a
# medium:   	33.17%
# large:   	32.6%
# 2:   	12.52%
# the:   	9.92%
# small:   	4.9%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium
# pot:   	70.28%
# speed:   	22.19%
# heat:   	1.89%
# skillet:   	1.72%
# bowl:   	1.44%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot
# of:   	63.55%
# and:   	19.69%
# .:   	14.54%
# ,:   	1.45%
# but:   	0.22%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of
# the:   	44.48%
# boiling:   	33.45%
# a:   	5.55%
# until:   	4.63%
# pot:   	3.56%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling
# water:   	96.05%
# salted:   	2.03%
# until:   	1.24%
# stock:   	0.32%
# frequently:   	0.13%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water
# ;:   	82.57%
# to:   	13.52%
# and:   	2.56%
# ,:   	0.53%
# are:   	0.38%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ;
# add:   	65.4%
# cook:   	10.57%
# fluff:   	5.44%
# simmer:   	4.67%
# bring:   	3.87%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add
# the:   	92.28%
# a:   	2.04%
# mixture:   	1.13%
# chard:   	0.88%
# broth:   	0.57%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the
# mushrooms:   	26.54%
# broth:   	16.29%
# the:   	13.73%
# pot:   	5.09%
# water:   	4.77%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the
# the:   	21.51%
# mushrooms:   	16.54%
# broth:   	15.19%
# mixture:   	7.66%
# chard:   	6.96%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers
# and:   	99.9%
# until:   	0.07%
# is:   	0.02%
# ,:   	0.01%
# salted:   	0.0%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and
# cook:   	66.07%
# the:   	8.66%
# add:   	8.07%
# vegetables:   	3.53%
# stirring:   	2.44%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add
# the:   	73.09%
# mixture:   	12.63%
# a:   	10.52%
# juice:   	1.19%
# broth:   	0.54%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture
# until:   	91.45%
# in:   	6.79%
# over:   	0.63%
# ,:   	0.36%
# ;:   	0.35%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until
# absorbed:   	32.03%
# it:   	29.38%
# they:   	7.45%
# smooth:   	5.99%
# very:   	3.27%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed
# ,:   	68.44%
# and:   	23.5%
# until:   	3.79%
# .:   	1.65%
# is:   	1.0%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed ,
# and:   	44.65%
# stirring:   	31.98%
# about:   	12.69%
# until:   	4.31%
# cook:   	3.31%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about
# 2:   	26.16%
# 1:   	23.57%
# the:   	18.27%
# 5:   	10.25%
# 3:   	9.14%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the
# sauce:   	61.31%
# mushrooms:   	10.14%
# chard:   	6.27%
# beans:   	4.7%
# cream:   	2.16%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard
# until:   	48.3%
# is:   	44.86%
# and:   	4.53%
# ,:   	1.23%
# heat:   	0.24%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until
# it:   	35.81%
# absorbed:   	11.75%
# wilted:   	8.43%
# they:   	6.1%
# smooth:   	5.51%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the
# pot:   	31.82%
# mixture:   	25.82%
# mushrooms:   	14.3%
# water:   	9.79%
# the:   	7.28%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water
# ;:   	91.88%
# and:   	4.96%
# to:   	2.21%
# ,:   	0.3%
# are:   	0.2%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ;
# cook:   	20.04%
# add:   	16.79%
# bring:   	16.72%
# simmer:   	16.12%
# drain:   	10.66%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff
# ,:   	83.66%
# to:   	13.89%
# .:   	1.0%
# a:   	0.27%
# into:   	0.26%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff ,
# and:   	94.29%
# until:   	1.82%
# stirring:   	1.65%
# cook:   	0.67%
# about:   	0.43%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and
# parsley:   	21.42%
# cook:   	15.01%
# red:   	10.1%
# the:   	6.22%
# chile:   	5.78%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley
# and:   	62.94%
# ,:   	36.72%
# with:   	0.1%
# to:   	0.07%
# in:   	0.05%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley ,
# and:   	97.11%
# parsley:   	0.6%
# stirring:   	0.54%
# about:   	0.52%
# until:   	0.34%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and
# parsley:   	40.72%
# dried:   	6.96%
# red:   	6.69%
# chile:   	6.31%
# basil:   	5.5%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile
# mixture:   	44.2%
# paste:   	11.14%
# the:   	8.43%
# juice:   	8.02%
# broth:   	7.08%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture
# in:   	62.77%
# until:   	30.86%
# over:   	4.45%
# ,:   	0.47%
# and:   	0.4%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture until
# it:   	46.29%
# absorbed:   	19.63%
# they:   	7.42%
# smooth:   	5.71%
# broth:   	3.07%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture until absorbed
# ,:   	62.57%
# and:   	29.43%
# until:   	2.58%
# .:   	1.99%
# with:   	1.19%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture until absorbed until
# it:   	32.54%
# absorbed:   	29.77%
# thickened:   	4.98%
# wilted:   	4.97%
# smooth:   	4.65%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture until absorbed until absorbed
# ,:   	52.58%
# and:   	35.53%
# until:   	4.36%
# is:   	3.12%
# .:   	1.53%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture until absorbed until absorbed ,
# and:   	58.03%
# stirring:   	22.24%
# about:   	8.41%
# until:   	6.01%
# cook:   	2.27%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture until absorbed until absorbed , stirring
# occasionally:   	80.36%
# frequently:   	15.06%
# ,:   	1.84%
# until:   	1.5%
# water:   	0.6%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture until absorbed until absorbed , stirring occasionally
# ,:   	90.14%
# with:   	7.22%
# to:   	1.47%
# .:   	0.69%
# and:   	0.43%
# --------
#
#
# PROMPT: roasted vegetables | chop 1 / 2 cup rice mixture in a medium pot of the sauce and add the mushrooms , and bring to large pot of until it is heated through , until absorbed , and add the the sauce until it ; add the bright . add a large bowl and cook until wilted . return a medium pot of boiling water ; add the the peppers and add mixture until absorbed , about the chard until the water ; fluff , and parsley , and chile mixture until absorbed until absorbed , stirring occasionally ,
# until:   	70.92%
# and:   	26.71%
# stirring:   	1.43%
# about:   	0.26%
# the:   	0.13%
# --------
